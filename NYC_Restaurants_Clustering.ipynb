# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://ibm.box.com/shared/static/9gegpsmnsoo25ikkbl4qzlvlyjbgxs5x.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Segmenting and Clustering Neighborhoods in New York City</font></h1>

# %% [markdown]
# ## Introduction
#
# In this lab, you will learn how to convert addresses into their equivalent latitude and longitude values. Also, you will use the Foursquare API to explore neighborhoods in New York City. You will use the **explore** function to get the most common venue categories in each neighborhood, and then use this feature to group the neighborhoods into clusters. You will use the *k*-means clustering algorithm to complete this task. Finally, you will use the Folium library to visualize the neighborhoods in New York City and their emerging clusters.

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item1">Download and Explore Dataset</a>
#
# 2. <a href="#item2">Explore Neighborhoods in New York City</a>
#
# 3. <a href="#item3">Analyze Each Neighborhood</a>
#
# 4. <a href="#item4">Cluster Neighborhoods</a>
#
# 5. <a href="#item5">Examine Clusters</a>
# </font>
# </div>

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# ## 1. Download and Explore Dataset

# %% [markdown]
# First, let's download a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood from https://geo.nyu.edu/download/file/nyu-2451-34572-geojson.json:

# %%
# !wget -q -O 'newyork_data_2.json' https://geo.nyu.edu/download/file/nyu-2451-34572-geojson.json
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# #### Load and explore the data

# %% [markdown]
# Next, let's load the data.

# %%
with open('newyork_data_2.json') as json_data:
    newyork_data = json.load(json_data)

# %% [markdown]
# All the relevant data is in the *features* key, which is basically a list of the neighborhoods. So, let's define a new variable that includes this data.

# %%
neighborhoods_data = newyork_data['features']

# %% [markdown]
# Let's take a look at the first item in this list.

# %%
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %% [markdown]
# #### Tranform the data into a *pandas* dataframe

# %% [markdown]
# Let's transform this data of nested Python dictionaries into a *pandas* dataframe:

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# Let's loop through the data and fill the dataframe one row at a time.

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': "%s (%s)" % (neighborhood_name, borough),
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of New York City.

# %%
address = 'New York City, NY'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7308619, -73.9871558.

# %% [markdown]
# #### Create a map of New York with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Define function to extract single borough's neighborhoods:

# %%
def getBoroughData(neighborhoods, borough):
    return neighborhoods[neighborhoods['Borough'] == borough].reset_index(drop=True)

# %% [markdown]
# Let's check it by extracting Brooklyn's neighborhoods, for example:

# %%
borough_data = getBoroughData(neighborhoods, 'Brooklyn')
borough_data.head()
# Out:
#     Borough            Neighborhood   Latitude  Longitude
# 0  Brooklyn    Bay Ridge (Brooklyn)  40.625801 -74.030621
# 1  Brooklyn  Bensonhurst (Brooklyn)  40.611009 -73.995180
# 2  Brooklyn  Sunset Park (Brooklyn)  40.645103 -74.010316
# 3  Brooklyn   Greenpoint (Brooklyn)  40.730201 -73.954241
# 4  Brooklyn    Gravesend (Brooklyn)  40.595260 -73.973471

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'BB5MFHHS4VO3ZJTB12ETQUO4JXRMTNFJWHODUBG24FP0BAOS' # your Foursquare ID
CLIENT_SECRET = 'HD4MMSKQ1XUM4DUMHGLVWNVOTQNSDHDXT3MCA3EY4RUY2IRL' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BB5MFHHS4VO3ZJTB12ETQUO4JXRMTNFJWHODUBG24FP0BAOS
# CLIENT_SECRET:HD4MMSKQ1XUM4DUMHGLVWNVOTQNSDHDXT3MCA3EY4RUY2IRL

# %% [markdown]
# Define function to get nearby restaurants:

# %%
def getNearbyRestaurants(neighborhood_data, client_id, client_secret, version = '20180605', radius=500, limit = 100):
    
    categoryId = '4d4b7105d754a06374d81259'   # Foursquare's Restaurants category
    venues_list=[]
    for name, lat, lng in zip(neighborhood_data['Neighborhood'], neighborhood_data['Latitude'], neighborhood_data['Longitude']):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            client_id, 
            client_secret, 
            version, 
            lat, 
            lng, 
            radius, 
            limit,
            categoryId)
            
        # make the GET request
        results = requests.get(url).json()["response"]['venues']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['name'], 
            v['location']['lat'], 
            v['location']['lng'],  
            v['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Get Brooklyn restaurants:

# %%
neighborhood_data = getBoroughData(neighborhoods, 'Brooklyn')
brooklyn_restaurants = getNearbyRestaurants(neighborhood_data, CLIENT_ID, CLIENT_SECRET)
brooklyn_restaurants.shape
# Out:
# (3132, 7)

# %% [markdown]
# Get Queens restaurants:

# %%
neighborhood_data = getBoroughData(neighborhoods, 'Queens')
queens_restaurants = getNearbyRestaurants(neighborhood_data, CLIENT_ID, CLIENT_SECRET)
queens_restaurants.shape
# Out:
# (2855, 7)

# %% [markdown]
# Get Manhattan restaurants:

# %%
neighborhood_data = getBoroughData(neighborhoods, 'Manhattan')
manhattan_restaurants = getNearbyRestaurants(neighborhood_data, CLIENT_ID, CLIENT_SECRET)
manhattan_restaurants.shape
# Out:
# (2000, 7)

# %% [markdown]
# Get Bronx restaurants:

# %%
neighborhood_data = getBoroughData(neighborhoods, 'Bronx')
bronx_restaurants = getNearbyRestaurants(neighborhood_data, CLIENT_ID, CLIENT_SECRET)
bronx_restaurants.shape
# Out:
# (2160, 7)

# %% [markdown]
# Get Staten Island restaurants:

# %%
neighborhood_data = getBoroughData(neighborhoods, 'Staten Island')
staten_restaurants = getNearbyRestaurants(neighborhood_data, CLIENT_ID, CLIENT_SECRET)
staten_restaurants.shape
# Out:
# (1452, 7)

# %% [markdown]
# Let's take a look at categories counts for one of the boroughs:

# %%
brooklyn_restaurants['Venue Category'].value_counts()
# Out:
# Deli / Bodega                      322
# Pizza Place                        207
# Food                               198
# Coffee Shop                        180
# Chinese Restaurant                 163
# Bakery                             154
# Caribbean Restaurant               130
# Italian Restaurant                  95
# Café                                94
# Fast Food Restaurant                80
# American Restaurant                 79
# Mexican Restaurant                  76
# Bagel Shop                          72
# Donut Shop                          71
# Restaurant                          51
# Sandwich Place                      51
# Food Truck                          51
# Fried Chicken Joint                 48
# Ice Cream Shop                      48
# Seafood Restaurant                  42
# Sushi Restaurant                    42
# Burger Joint                        41
# Diner                               37
# Latin American Restaurant           36
# Juice Bar                           32
# Thai Restaurant                     32
# Asian Restaurant                    29
# Dessert Shop                        29
# Japanese Restaurant                 28
# Spanish Restaurant                  25
# New American Restaurant             24
# Breakfast Spot                      24
# French Restaurant                   23
# Taco Place                          20
# Middle Eastern Restaurant           20
# Southern / Soul Food Restaurant     18
# Bar                                 17
# Indian Restaurant                   16
# BBQ Joint                           15
# Turkish Restaurant                  15
# Falafel Restaurant                  14
# Ramen Restaurant                    13
# Grocery Store                       13
# Vegetarian / Vegan Restaurant       13
# Steakhouse                          13
# Cocktail Bar                        12
# Eastern European Restaurant         12
# Bubble Tea Shop                     11
# Vietnamese Restaurant               11
# Convenience Store                   10
# Russian Restaurant                  10
# Food Court                           9
# Salad Place                          9
# Gastropub                            8
# Korean Restaurant                    8
# Snack Place                          7
# Greek Restaurant                     7
# Candy Store                          6
# Mediterranean Restaurant             6
# Burrito Place                        6
# Kosher Restaurant                    6
# South American Restaurant            6
# Frozen Yogurt Shop                   6
# Hot Dog Joint                        6
# Creperie                             5
# Lounge                               5
# Pub                                  5
# Cantonese Restaurant                 5
# African Restaurant                   5
# Pie Shop                             5
# Food Stand                           5
# Tea Room                             4
# Beer Garden                          4
# Wings Joint                          4
# Cupcake Shop                         4
# Gourmet Shop                         4
# Buffet                               4
# Tapas Restaurant                     4
# Poke Place                           4
# Wine Bar                             3
# Cuban Restaurant                     3
# Halal Restaurant                     3
# Cajun / Creole Restaurant            3
# Polish Restaurant                    3
# Dumpling Restaurant                  3
# Food & Drink Shop                    3
# Event Space                          3
# Supermarket                          3
# Israeli Restaurant                   3
# Hotpot Restaurant                    3
# Bistro                               3
# Noodle House                         3
# Arepa Restaurant                     3
# Jewish Restaurant                    2
# Gaming Cafe                          2
# Music Venue                          2
# Dive Bar                             2
# Hookah Bar                           2
# Soup Place                           2
# Filipino Restaurant                  2
# German Restaurant                    2
# Pakistani Restaurant                 2
# Peruvian Restaurant                  2
# Gym / Fitness Center                 2
# Factory                              2
# Comfort Food Restaurant              2
# Fish & Chips Shop                    2
# Hotel Bar                            2
# Dim Sum Restaurant                   2
# Clothing Store                       1
# Lebanese Restaurant                  1
# Szechuan Restaurant                  1
# Irish Pub                            1
# Empanada Restaurant                  1
# Mac & Cheese Joint                   1
# Gift Shop                            1
# Beer Store                           1
# Farmers Market                       1
# Indian Chinese Restaurant            1
# Tibetan Restaurant                   1
# Varenyky restaurant                  1
# Fruit & Vegetable Store              1
# Shanghai Restaurant                  1
# Health Food Store                    1
# Art Gallery                          1
# Gluten-free Restaurant               1
# Fish Market                          1
# Argentinian Restaurant               1
# Shabu-Shabu Restaurant               1
# Used Bookstore                       1
# Taiwanese Restaurant                 1
# Whisky Bar                           1
# Gym                                  1
# Furniture / Home Store               1
# Cafeteria                            1
# Moroccan Restaurant                  1
# Kebab Restaurant                     1
# Record Shop                          1
# Colombian Restaurant                 1
# Salvadoran Restaurant                1
# Brazilian Restaurant                 1
# Sports Bar                           1
# Butcher                              1
# Name: Venue Category, dtype: int64

# %% [markdown]
# There are a lot of generic categories that would not be useful in our analysis. Let's filter them out and leave only categories that may hint at some particular ethnic background.
#
# Define a function to clean up venues list:

# %%
def cleanupRestaurants(restaurants):
    keeps = [
    #'American Restaurant',
    'Italian Restaurant',
    'Mexican Restaurant',
    'Chinese Restaurant',
    'French Restaurant',
    #'New American Restaurant',
    'Ramen Restaurant',
    'Thai Restaurant',
    'Mediterranean Restaurant',
    'Japanese Restaurant',
    'Indian Restaurant',
    'Spanish Restaurant',
    'Sushi Restaurant',
    'Latin American Restaurant',
    'Asian Restaurant',
    'Greek Restaurant',
    'Taco Place',
    'Noodle House',
    'Korean Restaurant',
    'Caribbean Restaurant',
    'Vietnamese Restaurant',
    'Tapas Restaurant',
    'Dim Sum Restaurant',
    'Cuban Restaurant',
    'Dumpling Restaurant',
    'Udon Restaurant',
    'Falafel Restaurant',
    'Lebanese Restaurant',
    'Burrito Place',
    'Southern / Soul Food Restaurant',
    'German Restaurant',
    'Beer Garden',
    'Filipino Restaurant',
    'Australian Restaurant',
    'Swiss Restaurant',
    'Moroccan Restaurant',
    'Peruvian Restaurant',
    'Sake Bar',
    'Ethiopian Restaurant',
    'Middle Eastern Restaurant',
    'Poke Place',
    'Taiwanese Restaurant',
    'Malay Restaurant',
    'Szechuan Restaurant',
    'Hawaiian Restaurant',
    'Soba Restaurant',
    'Turkish Restaurant',
    'Kosher Restaurant',
    'Israeli Restaurant',
    'Jewish Restaurant',
    'Cantonese Restaurant',
    'South Indian Restaurant',
    'Creperie',
    'Shanghai Restaurant',
    'Arepa Restaurant',
    'African Restaurant',
    'Tex-Mex Restaurant',
    'Irish Pub',
    'Halal Restaurant',
    'English Restaurant',
    'Paella Restaurant',
    'Japanese Curry Restaurant',
    'Kebab Restaurant',
    'Argentinian Restaurant',
    'Ukrainian Restaurant'
    ]
    
    return restaurants.loc[restaurants['Venue Category'].isin(keeps)]

# %%
brooklyn_restaurants_cleaned = cleanupRestaurants(brooklyn_restaurants)
queens_restaurants_cleaned = cleanupRestaurants(queens_restaurants)
manhattan_restaurants_cleaned = cleanupRestaurants(manhattan_restaurants)
bronx_restaurants_cleaned = cleanupRestaurants(bronx_restaurants)
staten_restaurants_cleaned = cleanupRestaurants(staten_restaurants)
brooklyn_restaurants_cleaned.shape
queens_restaurants_cleaned.shape
manhattan_restaurants_cleaned.shape
bronx_restaurants_cleaned.shape
staten_restaurants_cleaned.shape
# Out:
# (367, 7)

# %% [markdown]
# Concatenate boroughs data sets:

# %%
nyc_restaurants = pd.concat([brooklyn_restaurants_cleaned, queens_restaurants_cleaned, manhattan_restaurants_cleaned, bronx_restaurants_cleaned, staten_restaurants_cleaned])
nyc_restaurants.shape
# Out:
# (3343, 7)

# %% [markdown]
# Define function to get frequencies:

# %%
def getFrequencies(venues):
    # one hot encoding
    onehot = pd.get_dummies(venues[['Venue Category']], prefix="", prefix_sep="")
    
    # add neighborhood column back to dataframe
    onehot['Neighborhood'] = venues['Neighborhood'] 

    # move neighborhood column to the first column
    fixed_columns = [onehot.columns[-1]] + list(onehot.columns[:-1])
    onehot = onehot[fixed_columns]
    
    # get frequencies
    return onehot.groupby('Neighborhood').mean().reset_index()

#brooklyn_grouped = getFrequencies(brooklyn_restaurants)
#brooklyn_grouped

# %% [markdown]
# Function to sort venues in descending order:

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Clustering:

# %%
nyc_grouped = getFrequencies(nyc_restaurants)
nyc_grouped.sort_values(by='Neighborhood')
nyc_grouped.shape
# Out:
# (291, 64)

# %% [markdown]
# Function to find optimal clusters number using silhouette score:

# %%
from sklearn.metrics import silhouette_score

def findOptimalK(grouped_for_clustering, kmax = 20):
    # get frequencies
    max_score = 0
    opt_clusters = 0

    #grouped_for_clustering = freqs.drop('Neighborhood', 1)
    
    for kclusters in range(3, kmax):    # [2, 3, 4, 5, 6, 7, 8, 9]:
        cluster_labels = KMeans(n_clusters=kclusters, random_state=0).fit_predict(grouped_for_clustering)
        silhouette_avg = silhouette_score(grouped_for_clustering, cluster_labels)
        print("For n_clusters =", kclusters, "The average silhouette_score is :", silhouette_avg, "labels =: ", len(cluster_labels))
        if (silhouette_avg > max_score):
            max_score = silhouette_avg
            opt_clusters = kclusters
    
    return opt_clusters

def findClusters(freqs):
    grouped_for_clustering = freqs.drop('Neighborhood', 1)

    # set number of clusters
    kclusters = findOptimalK(grouped_for_clustering)

    # run k-means clustering
    cluster_labels = KMeans(n_clusters=kclusters, random_state=0).fit_predict(grouped_for_clustering)
    print("labels =: ", len(cluster_labels))
    
    return (kclusters, cluster_labels)

# %%
nyc_grouped.shape
# Out:
# (291, 64)

# %%
k_clusters, labels = findClusters(nyc_grouped)
# Out:
# For n_clusters = 3 The average silhouette_score is : 0.1594182612197137 labels =:  291
# For n_clusters = 4 The average silhouette_score is : 0.17512347647915594 labels =:  291
# For n_clusters = 5 The average silhouette_score is : 0.15480323139950145 labels =:  291
# For n_clusters = 6 The average silhouette_score is : 0.15670265663812336 labels =:  291
# For n_clusters = 7 The average silhouette_score is : 0.15797086577112154 labels =:  291
# For n_clusters = 8 The average silhouette_score is : 0.15396317697018455 labels =:  291
# For n_clusters = 9 The average silhouette_score is : 0.15523497813217546 labels =:  291
# For n_clusters = 10 The average silhouette_score is : 0.1339339915921139 labels =:  291
# For n_clusters = 11 The average silhouette_score is : 0.15183515788376128 labels =:  291
# For n_clusters = 12 The average silhouette_score is : 0.16208708484098897 labels =:  291
# For n_clusters = 13 The average silhouette_score is : 0.1396968508131247 labels =:  291
# For n_clusters = 14 The average silhouette_score is : 0.13294590255709188 labels =:  291
# For n_clusters = 15 The average silhouette_score is : 0.14460482750754905 labels =:  291
# For n_clusters = 16 The average silhouette_score is : 0.14601338733422822 labels =:  291
# For n_clusters = 17 The average silhouette_score is : 0.15857595384007378 labels =:  291
# For n_clusters = 18 The average silhouette_score is : 0.14990086728855365 labels =:  291
# For n_clusters = 19 The average silhouette_score is : 0.13204217414810715 labels =:  291
# labels =:  291

# %%
len(labels)
k_clusters
# Out:
# 4

# %% [markdown]
# Create dataset with top 10 venues for neighborhood:

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = nyc_grouped['Neighborhood']

for ind in np.arange(nyc_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(nyc_grouped.iloc[ind, :], num_top_venues)
    
neighborhoods_venues_sorted.head()
# Out:
#                 Neighborhood 1st Most Common Venue  2nd Most Common Venue  \
# 0           Allerton (Bronx)    Mexican Restaurant     Chinese Restaurant
# 1   Annadale (Staten Island)      Sushi Restaurant  Vietnamese Restaurant
# 2  Arlington (Staten Island)  Caribbean Restaurant    Peruvian Restaurant
# 3   Arrochar (Staten Island)    Italian Restaurant             Taco Place
# 4           Arverne (Queens)       Thai Restaurant     Chinese Restaurant
#
#        3rd Most Common Venue      4th Most Common Venue  \
# 0         Spanish Restaurant      Vietnamese Restaurant
# 1       Ethiopian Restaurant        Japanese Restaurant
# 2      Vietnamese Restaurant         Falafel Restaurant
# 3  Middle Eastern Restaurant  Latin American Restaurant
# 4      Vietnamese Restaurant        Hawaiian Restaurant
#
#        5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 0           Halal Restaurant        Filipino Restaurant     French Restaurant
# 1  Japanese Curry Restaurant         Italian Restaurant    Israeli Restaurant
# 2        Japanese Restaurant  Japanese Curry Restaurant    Italian Restaurant
# 3   Mediterranean Restaurant         Chinese Restaurant     French Restaurant
# 4        Filipino Restaurant          French Restaurant     German Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0     German Restaurant      Greek Restaurant    Hawaiian Restaurant
# 1             Irish Pub     Indian Restaurant    Hawaiian Restaurant
# 2    Israeli Restaurant             Irish Pub      Indian Restaurant
# 3     German Restaurant      Greek Restaurant       Halal Restaurant
# 4      Greek Restaurant      Halal Restaurant      Indian Restaurant

# %%
neighborhoods.shape
# Out:
# (306, 4)

# %%
nyc_grouped.shape
# Out:
# (291, 64)

# %%
nyc_merged = neighborhoods.loc[neighborhoods['Neighborhood'].isin(nyc_grouped['Neighborhood'])].sort_values(by='Neighborhood')
nyc_merged.shape
# Out:
# (291, 4)

# %% [markdown]
# Now let's add cluster labels to our dataset:

# %%
# add clustering labels
nyc_merged['Cluster Labels'] = labels

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
nyc_merged = nyc_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

nyc_merged.head() # check the last columns!
# Out:
#            Borough               Neighborhood   Latitude  Longitude  \
# 298          Bronx           Allerton (Bronx)  40.865788 -73.859319
# 215  Staten Island   Annadale (Staten Island)  40.538114 -74.178549
# 227  Staten Island  Arlington (Staten Island)  40.635325 -74.165104
# 228  Staten Island   Arrochar (Staten Island)  40.596313 -74.067124
# 177         Queens           Arverne (Queens)  40.589144 -73.791992
#
#      Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 298               3    Mexican Restaurant     Chinese Restaurant
# 215               0      Sushi Restaurant  Vietnamese Restaurant
# 227               2  Caribbean Restaurant    Peruvian Restaurant
# 228               0    Italian Restaurant             Taco Place
# 177               3       Thai Restaurant     Chinese Restaurant
#
#          3rd Most Common Venue      4th Most Common Venue  \
# 298         Spanish Restaurant      Vietnamese Restaurant
# 215       Ethiopian Restaurant        Japanese Restaurant
# 227      Vietnamese Restaurant         Falafel Restaurant
# 228  Middle Eastern Restaurant  Latin American Restaurant
# 177      Vietnamese Restaurant        Hawaiian Restaurant
#
#          5th Most Common Venue      6th Most Common Venue  \
# 298           Halal Restaurant        Filipino Restaurant
# 215  Japanese Curry Restaurant         Italian Restaurant
# 227        Japanese Restaurant  Japanese Curry Restaurant
# 228   Mediterranean Restaurant         Chinese Restaurant
# 177        Filipino Restaurant          French Restaurant
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 298     French Restaurant     German Restaurant      Greek Restaurant
# 215    Israeli Restaurant             Irish Pub     Indian Restaurant
# 227    Italian Restaurant    Israeli Restaurant             Irish Pub
# 228     French Restaurant     German Restaurant      Greek Restaurant
# 177     German Restaurant      Greek Restaurant      Halal Restaurant
#
#     10th Most Common Venue
# 298    Hawaiian Restaurant
# 215    Hawaiian Restaurant
# 227      Indian Restaurant
# 228       Halal Restaurant
# 177      Indian Restaurant

# %% [markdown]
# Let's visualize the resulting clusters:

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(k_clusters)
ys = [i+x+(i*x)**2 for i in range(k_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(nyc_merged['Latitude'], nyc_merged['Longitude'], nyc_merged['Neighborhood'], nyc_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster + 1), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
        
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Let's Examine Clusters:

# %% [markdown]
# #### Cluster 1

# %%
nyc_merged.loc[nyc_merged['Cluster Labels'] == 0, nyc_merged.columns[[1] + list(range(5, nyc_merged.shape[1]))]]
# Out:
#                              Neighborhood      1st Most Common Venue  \
# 215              Annadale (Staten Island)           Sushi Restaurant
# 228              Arrochar (Staten Island)         Italian Restaurant
# 129                      Astoria (Queens)           Greek Restaurant
# 152                   Auburndale (Queens)          Korean Restaurant
# 79                  Bath Beach (Brooklyn)         Chinese Restaurant
# 127         Battery Park City (Manhattan)         Mexican Restaurant
# 46                   Bay Ridge (Brooklyn)         Italian Restaurant
# 175                  Bay Terrace (Queens)           Asian Restaurant
# 151                      Bayside (Queens)           Sushi Restaurant
# 63          Bedford Stuyvesant (Brooklyn)         Mexican Restaurant
# 91                Bergen Beach (Brooklyn)        Japanese Restaurant
# 278                   Blissville (Queens)          Indian Restaurant
# 87                 Boerum Hill (Brooklyn)          French Restaurant
# 80                Borough Park (Brooklyn)          Kosher Restaurant
# 159                    Briarwood (Queens)          Indian Restaurant
# 51              Brighton Beach (Brooklyn)                 Taco Place
# 282          Broadway Junction (Brooklyn)        Japanese Restaurant
# 64            Brooklyn Heights (Brooklyn)         Italian Restaurant
# 246            Bulls Head (Staten Island)         Chinese Restaurant
# 62                    Bushwick (Brooklyn)         Mexican Restaurant
# 247             Carnegie Hill (Manhattan)         Italian Restaurant
# 66             Carroll Gardens (Brooklyn)         Italian Restaurant
# 40                    Castle Hill (Bronx)         Spanish Restaurant
# 239            Charleston (Staten Island)        Japanese Restaurant
# 116                   Chelsea (Manhattan)         Italian Restaurant
# 249              Civic Center (Manhattan)          French Restaurant
# 113                   Clinton (Manhattan)        Japanese Restaurant
# 84                Clinton Hill (Brooklyn)         Italian Restaurant
# 65                 Cobble Hill (Brooklyn)            Thai Restaurant
# 149                College Point (Queens)  Latin American Restaurant
# 268             Concourse Village (Bronx)         Mexican Restaurant
# 78                Coney Island (Brooklyn)         Mexican Restaurant
# 134                       Corona (Queens)         Mexican Restaurant
# 71               Cypress Hills (Brooklyn)  Latin American Restaurant
# 154                   Douglaston (Queens)         Italian Restaurant
# 86                    Downtown (Brooklyn)         Mexican Restaurant
# 283                      Dumbo (Brooklyn)         Italian Restaurant
# 81               Dyker Heights (Brooklyn)            Thai Restaurant
# 106               East Harlem (Manhattan)         Mexican Restaurant
# 17                   East Tremont (Bronx)         Chinese Restaurant
# 118              East Village (Manhattan)       Taiwanese Restaurant
# 95           East Williamsburg (Brooklyn)        Japanese Restaurant
# 258              Elm Park (Staten Island)         Italian Restaurant
# 132                     Elmhurst (Queens)            Thai Restaurant
# 214           Eltingville (Staten Island)         Chinese Restaurant
# 3                       Fieldston (Bronx)          German Restaurant
# 128        Financial District (Manhattan)         Italian Restaurant
# 54                    Flatbush (Brooklyn)       Caribbean Restaurant
# 276                  Flatiron (Manhattan)         Italian Restaurant
# 181                  Floral Park (Queens)          Indian Restaurant
# 138                     Flushing (Queens)         Chinese Restaurant
# 16                        Fordham (Bronx)         Mexican Restaurant
# 135                 Forest Hills (Queens)            Thai Restaurant
# 196         Forest Hills Gardens (Queens)         Italian Restaurant
# 69                 Fort Greene (Brooklyn)         Italian Restaurant
# 99               Fort Hamilton (Brooklyn)         Chinese Restaurant
# 82             Gerritsen Beach (Brooklyn)           Sushi Restaurant
# 155                    Glen Oaks (Queens)           Greek Restaurant
# 68                     Gowanus (Brooklyn)         Italian Restaurant
# 126                  Gramercy (Manhattan)         Italian Restaurant
# 226          Graniteville (Staten Island)  Latin American Restaurant
# 233            Grant City (Staten Island)           Asian Restaurant
# 229              Grasmere (Staten Island)        Japanese Restaurant
# 213           Great Kills (Staten Island)         Italian Restaurant
# 49                  Greenpoint (Brooklyn)           Ramen Restaurant
# 242            Greenridge (Staten Island)           Asian Restaurant
# 117         Greenwich Village (Manhattan)   Mediterranean Restaurant
# 103          Hamilton Heights (Manhattan)         Mexican Restaurant
# 302                      Hammels (Queens)       Caribbean Restaurant
# 295              Highland Park (Brooklyn)       Caribbean Restaurant
# 289                  Homecrest (Brooklyn)         Chinese Restaurant
# 236              Huguenot (Staten Island)           Asian Restaurant
# 272                Hunters Point (Queens)         Italian Restaurant
# 24                    Hunts Point (Bronx)         Mexican Restaurant
# 102                    Inwood (Manhattan)         Mexican Restaurant
# 131              Jackson Heights (Queens)  Latin American Restaurant
# 160               Jamaica Center (Queens)       Caribbean Restaurant
# 183              Jamaica Estates (Queens)          Indian Restaurant
# 263                Jamaica Hills (Queens)          Indian Restaurant
# 57                  Kensington (Brooklyn)         Mexican Restaurant
# 157            Kew Gardens Hills (Queens)           Sushi Restaurant
# 109                Lenox Hill (Manhattan)         Italian Restaurant
# 112            Lincoln Square (Manhattan)          French Restaurant
# 121              Little Italy (Manhattan)         Chinese Restaurant
# 153                  Little Neck (Queens)         Chinese Restaurant
# 139             Long Island City (Queens)         Mexican Restaurant
# 119           Lower East Side (Manhattan)         Mexican Restaurant
# 296                    Madison (Brooklyn)         Chinese Restaurant
# 77             Manhattan Beach (Brooklyn)         Turkish Restaurant
# 53           Manhattan Terrace (Brooklyn)           Sushi Restaurant
# 124          Manhattan Valley (Manhattan)         Italian Restaurant
# 104            Manhattanville (Manhattan)         Chinese Restaurant
# 6                 Marble Hill (Manhattan)         Mexican Restaurant
# 83                 Marine Park (Brooklyn)         Mexican Restaurant
# 20                        Melrose (Bronx)         African Restaurant
# 114                   Midtown (Manhattan)        Japanese Restaurant
# 250             Midtown South (Manhattan)          Korean Restaurant
# 92                     Midwood (Brooklyn)         Falafel Restaurant
# 125       Morningside Heights (Manhattan)         Chinese Restaurant
# 115               Murray Hill (Manhattan)           Ramen Restaurant
# 180                  Murray Hill (Queens)          Korean Restaurant
# 211              New Dorp (Staten Island)         Italian Restaurant
# 248                      Noho (Manhattan)         Italian Restaurant
# 195                 North Corona (Queens)         Spanish Restaurant
# 36                North Riverdale (Bronx)         Italian Restaurant
# 96                  North Side (Brooklyn)         Italian Restaurant
# 8                         Norwood (Bronx)         Mexican Restaurant
# 161              Oakland Gardens (Queens)          Korean Restaurant
# 98               Ocean Parkway (Brooklyn)           Sushi Restaurant
# 230              Old Town (Staten Island)         Italian Restaurant
# 147                   Ozone Park (Queens)         Spanish Restaurant
# 70                  Park Slope (Brooklyn)         Italian Restaurant
# 30                    Parkchester (Bronx)       Caribbean Restaurant
# 265                      Pomonok (Queens)         Spanish Restaurant
# 22                    Port Morris (Bronx)  Latin American Restaurant
# 205         Port Richmond (Staten Island)         Mexican Restaurant
# 59            Prospect Heights (Brooklyn)            Thai Restaurant
# 88   Prospect Lefferts Gardens (Brooklyn)       Caribbean Restaurant
# 304                 Queensbridge (Queens)         Italian Restaurant
# 186                   Ravenswood (Queens)         Italian Restaurant
# 67                    Red Hook (Brooklyn)         Mexican Restaurant
# 145                    Rego Park (Queens)         Chinese Restaurant
# 137                Richmond Hill (Queens)          Indian Restaurant
# 293       Richmond Valley (Staten Island)         Chinese Restaurant
# 143                    Ridgewood (Queens)           Greek Restaurant
# 4                       Riverdale (Bronx)         Italian Restaurant
# 178               Rockaway Beach (Queens)         Chinese Restaurant
# 110          Roosevelt Island (Manhattan)         Italian Restaurant
# 288                      Roxbury (Queens)                  Irish Pub
# 286          Sandy Ground (Staten Island)           Greek Restaurant
# 38                  Schuylerville (Bronx)         Chinese Restaurant
# 52              Sheepshead Bay (Brooklyn)         Italian Restaurant
# 122                      Soho (Manhattan)          French Restaurant
# 97                  South Side (Brooklyn)         Mexican Restaurant
# 35                 Spuyten Duyvil (Bronx)            Thai Restaurant
# 199             Stapleton (Staten Island)         Spanish Restaurant
# 173                     Steinway (Queens)           Sushi Restaurant
# 275           Stuyvesant Town (Manhattan)         Chinese Restaurant
# 140                    Sunnyside (Queens)         Chinese Restaurant
# 277            Sunnyside Gardens (Queens)          Korean Restaurant
# 48                 Sunset Park (Brooklyn)         Chinese Restaurant
# 271              Sutton Place (Manhattan)         Italian Restaurant
# 218         Tompkinsville (Staten Island)         Mexican Restaurant
# 120                   Tribeca (Manhattan)         Italian Restaurant
# 274                Tudor City (Manhattan)         Mexican Restaurant
# 273                Turtle Bay (Manhattan)           Ramen Restaurant
# 44                      Unionport (Bronx)         Spanish Restaurant
# 107           Upper East Side (Manhattan)         Italian Restaurant
# 111           Upper West Side (Manhattan)         Italian Restaurant
# 264                       Utopia (Queens)         Spanish Restaurant
# 32                       Van Nest (Bronx)         Chinese Restaurant
# 280               Vinegar Hill (Brooklyn)         Mexican Restaurant
# 101        Washington Heights (Manhattan)         Mexican Restaurant
# 201         West Brighton (Staten Island)         Italian Restaurant
# 18                     West Farms (Bronx)       Caribbean Restaurant
# 31             Westchester Square (Bronx)         Spanish Restaurant
# 225           Westerleigh (Staten Island)           Sushi Restaurant
# 61                Williamsburg (Brooklyn)  Latin American Restaurant
# 58             Windsor Terrace (Brooklyn)         Italian Restaurant
# 146                    Woodhaven (Queens)  Latin American Restaurant
# 7                        Woodlawn (Bronx)         Chinese Restaurant
# 216               Woodrow (Staten Island)         Chinese Restaurant
# 130                     Woodside (Queens)        Filipino Restaurant
# 108                 Yorkville (Manhattan)            Thai Restaurant
#
#                2nd Most Common Venue            3rd Most Common Venue  \
# 215            Vietnamese Restaurant             Ethiopian Restaurant
# 228                       Taco Place        Middle Eastern Restaurant
# 129               Italian Restaurant        Latin American Restaurant
# 152               Italian Restaurant                 Sushi Restaurant
# 79                  Asian Restaurant             Cantonese Restaurant
# 127               Italian Restaurant                 Sushi Restaurant
# 46                  Greek Restaurant                  Thai Restaurant
# 175               Italian Restaurant         Mediterranean Restaurant
# 151                Indian Restaurant               Italian Restaurant
# 63               Japanese Restaurant               Chinese Restaurant
# 81        Cantonese Restaurant               Turkish Restaurant
# 106                 Taco Place               Spanish Restaurant
# 17          Mexican Restaurant               African Restaurant
# 118       Ukrainian Restaurant                 Halal Restaurant
# 95          Falafel Restaurant              Lebanese Restaurant
# 258         Mexican Restaurant               Spanish Restaurant
# 132      Vietnamese Restaurant                 Asian Restaurant
# 214         African Restaurant        Middle Eastern Restaurant
# 3          Japanese Restaurant        Japanese Curry Restaurant
# 128                Beer Garden                French Restaurant
# 54           Indian Restaurant               Spanish Restaurant
# 276              Burrito Place                 Ramen Restaurant
# 181   Mediterranean Restaurant            Vietnamese Restaurant
# 138         Dim Sum Restaurant            Vietnamese Restaurant
# 16   Latin American Restaurant               African Restaurant
# 135          Korean Restaurant             Caribbean Restaurant
# 196   Mediterranean Restaurant               Mexican Restaurant
# 69          Spanish Restaurant               Israeli Restaurant
# 99                   Irish Pub               Spanish Restaurant
# 82         Japanese Restaurant        Japanese Curry Restaurant
# 155          Indian Restaurant               Falafel Restaurant
# 68      Argentinian Restaurant                  Thai Restaurant
# 126          German Restaurant          South Indian Restaurant
# 226        Japanese Restaurant        Japanese Curry Restaurant
# 233          French Restaurant                 Greek Restaurant
# 229  Middle Eastern Restaurant               Chinese Restaurant
# 213          Indian Restaurant               Spanish Restaurant
# 49           French Restaurant                 Sushi Restaurant
# 242       Ethiopian Restaurant              Japanese Restaurant
# 117         Italian Restaurant               Chinese Restaurant
# 103          Indian Restaurant              Japanese Restaurant
# 302                 Taco Place               Chinese Restaurant
# 295         Spanish Restaurant  Southern / Soul Food Restaurant
# 289      Vietnamese Restaurant                         Creperie
# 236      Vietnamese Restaurant                 Greek Restaurant
# 272      Vietnamese Restaurant                 Ramen Restaurant
# 24        Ethiopian Restaurant        Japanese Curry Restaurant
# 102            Thai Restaurant        Latin American Restaurant
# 131   Mediterranean Restaurant           Argentinian Restaurant
# 160         Mexican Restaurant               Chinese Restaurant
# 183        Peruvian Restaurant               Mexican Restaurant
# 263           Halal Restaurant                  Thai Restaurant
# 57          Italian Restaurant              Japanese Restaurant
# 157        Japanese Restaurant                 Asian Restaurant
# 109                 Taco Place               Mexican Restaurant
# 112   Mediterranean Restaurant               Mexican Restaurant
# 121   Mediterranean Restaurant                 Swiss Restaurant
# 153        Japanese Restaurant             Cantonese Restaurant
# 139            Thai Restaurant               Chinese Restaurant
# 119        Japanese Restaurant            Vietnamese Restaurant
# 296         Italian Restaurant         Mediterranean Restaurant
# 77         Hawaiian Restaurant              Filipino Restaurant
# 53          Turkish Restaurant                Kosher Restaurant
# 124            Thai Restaurant               Israeli Restaurant
# 104         Spanish Restaurant                 Sushi Restaurant
# 6           Spanish Restaurant                  Thai Restaurant
# 83          Italian Restaurant                French Restaurant
# 20          Mexican Restaurant               Italian Restaurant
# 114         Italian Restaurant                       Taco Place
# 250        Lebanese Restaurant              Japanese Restaurant
# 92           Kosher Restaurant                 Asian Restaurant
# 125         Mexican Restaurant                 Greek Restaurant
# 115         Mexican Restaurant                       Taco Place
# 180      Vietnamese Restaurant                  Thai Restaurant
# 122            Australian Restaurant         Mexican Restaurant
# 97                  Ramen Restaurant        Dumpling Restaurant
# 35             Vietnamese Restaurant          French Restaurant
# 199                 Asian Restaurant         Italian Restaurant
# 173                 Ramen Restaurant            Thai Restaurant
# 275             Ethiopian Restaurant        Dumpling Restaurant
# 140                       Taco Place         Mexican Restaurant
# 277        Latin American Restaurant  Middle Eastern Restaurant
# 48                Italian Restaurant                   Creperie
# 271                  Thai Restaurant                Beer Garden
# 218               Spanish Restaurant           Asian Restaurant
# 120                 Asian Restaurant          Indian Restaurant
# 274                  Soba Restaurant          German Restaurant
# 273                 Greek Restaurant          German Restaurant
# 44               Japanese Restaurant           Halal Restaurant
# 107                 Tapas Restaurant              Burrito Place
# 111  Southern / Soul Food Restaurant         Mexican Restaurant
# 264               African Restaurant           Tapas Restaurant
# 32                        Taco Place         Spanish Restaurant
# 280                French Restaurant          German Restaurant
# 101                 Tapas Restaurant           Ramen Restaurant
# 201                German Restaurant                 Taco Place
# 18                  Asian Restaurant           Cuban Restaurant
# 31         Latin American Restaurant        Hawaiian Restaurant
# 225               Chinese Restaurant          French Restaurant
# 61              Caribbean Restaurant         Chinese Restaurant
# 58                   Thai Restaurant          Indian Restaurant
# 146                  Thai Restaurant           Asian Restaurant
# 7              Vietnamese Restaurant        Filipino Restaurant
# 216              Filipino Restaurant          French Restaurant
# 130              Japanese Restaurant               Noodle House
# 108                German Restaurant  Latin American Restaurant
#
#                8th Most Common Venue      9th Most Common Venue  \
# 215                        Irish Pub          Indian Restaurant
# 228                German Restaurant           Greek Restaurant
# 129                       Poke Place         Falafel Restaurant
# 152            Vietnamese Restaurant            Thai Restaurant
# 79                  Sushi Restaurant                 Poke Place
# 127                German Restaurant           Greek Restaurant
# 46                  Sushi Restaurant        Japanese Restaurant
# 175                 Halal Restaurant          French Restaurant
# 151                Korean Restaurant               Noodle House
# 63                Israeli Restaurant                  Irish Pub
# 91                         Irish Pub          Indian Restaurant
# 278                German Restaurant           Greek Restaurant
# 87                  Sushi Restaurant         Chinese Restaurant
# 80                         Irish Pub          Indian Restaurant
# 159               Israeli Restaurant                  Irish Pub
# 51                 French Restaurant          Indian Restaurant
# 282               Israeli Restaurant                  Irish Pub
# 64                 French Restaurant         Chinese Restaurant
# 246                  Thai Restaurant         Italian Restaurant
# 62                Chinese Restaurant          German Restaurant
# 247                 Ramen Restaurant         Israeli Restaurant
# 66                  Greek Restaurant         Chinese Restaurant
# 40                 German Restaurant           Greek Restaurant
# 239               Israeli Restaurant          Indian Restaurant
# 116                       Taco Place           Sushi Restaurant
# 249                German Restaurant           Greek Restaurant
# 113               Italian Restaurant                  Irish Pub
# 84         Latin American Restaurant         Falafel Restaurant
# 65         Middle Eastern Restaurant         Spanish Restaurant
# 149                    Burrito Place                 Taco Place
# 268               Spanish Restaurant           Cuban Restaurant
# 78                  Asian Restaurant           Sushi Restaurant
# 134                German Restaurant           Greek Restaurant
# 71                  Greek Restaurant           Halal Restaurant
# 154              Szechuan Restaurant  Latin American Restaurant
# 86                 French Restaurant        Shanghai Restaurant
# 283              Filipino Restaurant          French Restaurant
# 81                Mexican Restaurant           Sushi Restaurant
# 106                 Cuban Restaurant          French Restaurant
# 17         Latin American Restaurant          Indian Restaurant
# 118               Mexican Restaurant         Falafel Restaurant
# 95                  Ramen Restaurant          German Restaurant
# 258                French Restaurant          German Restaurant
# 132        Latin American Restaurant           Sushi Restaurant
# 214                      Beer Garden          French Restaurant
# 3                          Irish Pub          Indian Restaurant
# 128              Lebanese Restaurant                  Irish Pub
# 54         Latin American Restaurant  Middle Eastern Restaurant
# 276              Lebanese Restaurant          Indian Restaurant
# 181               Italian Restaurant         Israeli Restaurant
# 138                 Malay Restaurant                 Poke Place
# 16               Filipino Restaurant          French Restaurant
# 135               Chinese Restaurant           Sushi Restaurant
# 196                 Cuban Restaurant         Chinese Restaurant
# 69                 French Restaurant       Caribbean Restaurant
# 99                       Beer Garden           Asian Restaurant
# 82                         Irish Pub          Indian Restaurant
# 155              Hawaiian Restaurant          French Restaurant
# 68                  Sushi Restaurant         Chinese Restaurant
# 126               Mexican Restaurant   Mediterranean Restaurant
# 226                        Irish Pub          Indian Restaurant
# 233               Italian Restaurant                  Irish Pub
# 229               Israeli Restaurant                  Irish Pub
# 213                        Irish Pub           Asian Restaurant
# 49                Chinese Restaurant      Vietnamese Restaurant
# 242                        Irish Pub          Indian Restaurant
# 117                  Udon Restaurant         Falafel Restaurant
# 103                 Sushi Restaurant       Caribbean Restaurant
# 302                German Restaurant           Greek Restaurant
# 295                French Restaurant          German Restaurant
# 289               Turkish Restaurant                  Irish Pub
# 236                French Restaurant          German Restaurant
# 272                French Restaurant           Greek Restaurant
# 24                         Irish Pub          Indian Restaurant
# 102               Chinese Restaurant       Caribbean Restaurant
# 131                 Greek Restaurant        Peruvian Restaurant
# 160                 Asian Restaurant         Israeli Restaurant
# 183                 Halal Restaurant          French Restaurant
# 263             Caribbean Restaurant          German Restaurant
# 57                        Taco Place           Halal Restaurant
# 157                 Greek Restaurant           Halal Restaurant
# 109               English Restaurant  Latin American Restaurant
# 112                German Restaurant           Halal Restaurant
# 121               Mexican Restaurant               Noodle House
# 153              Szechuan Restaurant        Peruvian Restaurant
# 139                French Restaurant          German Restaurant
# 119              Filipino Restaurant          French Restaurant
# 296                German Restaurant           Greek Restaurant
# 77                  Greek Restaurant           Halal Restaurant
# 53                Chinese Restaurant          French Restaurant
# 124                French Restaurant               Noodle House
# 104              Dumpling Restaurant           Cuban Restaurant
# 6              Vietnamese Restaurant          French Restaurant
# 83                  Halal Restaurant        Hawaiian Restaurant
# 20                  Cuban Restaurant         Israeli Restaurant
# 114                 Sushi Restaurant      Vietnamese Restaurant
# 250        Japanese Curry Restaurant         Italian Restaurant
# 92             Vietnamese Restaurant          French Restaurant
# 125             Ethiopian Restaurant       Cantonese Restaurant
# 115               Turkish Restaurant              Burrito Place
# 180               Israeli Restaurant                  Irish Pub
# 211                Indian Restaurant      Vietnamese Restaurant
# 248                 Ramen Restaurant           Cuban Restaurant
# 195              Filipino Restaurant          French Restaurant
# 36               Filipino Restaurant          French Restaurant
# 96               Japanese Restaurant                Beer Garden
# 8                   Greek Restaurant           Halal Restaurant
# 161                 Tapas Restaurant         Tex-Mex Restaurant
# 98             Vietnamese Restaurant           Halal Restaurant
# 230                French Restaurant          German Restaurant
# 147               Falafel Restaurant      Vietnamese Restaurant
# 70                  Sushi Restaurant         Falafel Restaurant
# 30   Southern / Soul Food Restaurant           Halal Restaurant
# 265                German Restaurant           Greek Restaurant
# 22                 German Restaurant           Greek Restaurant
# 205                German Restaurant           Halal Restaurant
# 59         Latin American Restaurant           Ramen Restaurant
# 88                Falafel Restaurant           Tapas Restaurant
# 304                Indian Restaurant  Latin American Restaurant
# 186                 Tapas Restaurant           Ramen Restaurant
# 67                  Halal Restaurant        Hawaiian Restaurant
# 145               Italian Restaurant        Shanghai Restaurant
# 137              Peruvian Restaurant           Asian Restaurant
# 293                German Restaurant           Greek Restaurant
# 143               Turkish Restaurant         Italian Restaurant
# 4                   Asian Restaurant          Indian Restaurant
# 178                 Sushi Restaurant         Spanish Restaurant
# 110        Middle Eastern Restaurant       Caribbean Restaurant
# 288                Indian Restaurant        Hawaiian Restaurant
# 286                        Irish Pub          Indian Restaurant
# 38                  Greek Restaurant                 Taco Place
# 52             Vietnamese Restaurant          French Restaurant
# 122                 Swiss Restaurant      Vietnamese Restaurant
# 97               Japanese Restaurant           Asian Restaurant
# 35                 German Restaurant           Greek Restaurant
# 199              Peruvian Restaurant         Israeli Restaurant
# 173                        Irish Pub      Australian Restaurant
# 275        Latin American Restaurant            Thai Restaurant
# 140                 Sushi Restaurant        Japanese Restaurant
# 277                     Noodle House        Peruvian Restaurant
# 48                  Halal Restaurant          French Restaurant
# 271        Latin American Restaurant  Middle Eastern Restaurant
# 218                Indian Restaurant         Chinese Restaurant
# 120                German Restaurant           Greek Restaurant
# 274               Chinese Restaurant        Lebanese Restaurant
# 273              Lebanese Restaurant               Noodle House
# 44                Chinese Restaurant          French Restaurant
# 107            Vietnamese Restaurant           Greek Restaurant
# 111               Chinese Restaurant         Falafel Restaurant
# 264        Japanese Curry Restaurant         Israeli Restaurant
# 32              Caribbean Restaurant      Vietnamese Restaurant
# 280                 Greek Restaurant           Halal Restaurant
# 101                Indian Restaurant         Spanish Restaurant
# 201               Falafel Restaurant       Caribbean Restaurant
# 18                Mexican Restaurant          German Restaurant
# 31                 French Restaurant          German Restaurant
# 225                German Restaurant           Greek Restaurant
# 61                Mexican Restaurant         African Restaurant
# 58                  Greek Restaurant  Middle Eastern Restaurant
# 146                       Taco Place        Peruvian Restaurant
# 7                  French Restaurant          German Restaurant
# 216                German Restaurant           Greek Restaurant
# 130               Chinese Restaurant      Vietnamese Restaurant
# 108                Indian Restaurant           Ramen Restaurant
#
#               10th Most Common Venue
# 215              Hawaiian Restaurant
# 228                 Halal Restaurant
# 129                      Beer Garden
# 152                       Taco Place
# 79                 Indian Restaurant
# 127                 Halal Restaurant
# 46                        Taco Place
# 175                German Restaurant
# 151              Shanghai Restaurant
# 63                Falafel Restaurant
# 91               Hawaiian Restaurant
# 278            Vietnamese Restaurant
# 87                     Burrito Place
# 80               Hawaiian Restaurant
# 159               Falafel Restaurant
# 51          Mediterranean Restaurant
# 282                Indian Restaurant
# 64                  Sushi Restaurant
# 246                        Irish Pub
# 62                  Greek Restaurant
# 247                        Irish Pub
# 66               Hawaiian Restaurant
# 40               Hawaiian Restaurant
# 239              Hawaiian Restaurant
# 116                 Greek Restaurant
# 249                 Halal Restaurant
# 113                Indian Restaurant
# 84                Chinese Restaurant
# 65                     Burrito Place
# 149              Hawaiian Restaurant
# 268               Israeli Restaurant
# 78             Vietnamese Restaurant
# 134                 Halal Restaurant
# 71               Hawaiian Restaurant
# 154              Hawaiian Restaurant
# 86                Spanish Restaurant
# 283                German Restaurant
# 81                  Halal Restaurant
# 106  Southern / Soul Food Restaurant
# 17               Hawaiian Restaurant
# 118              Moroccan Restaurant
# 95               Filipino Restaurant
# 258                 Greek Restaurant
# 132                French Restaurant
# 214        Japanese Curry Restaurant
# 3                Hawaiian Restaurant
# 128               Falafel Restaurant
# 54                          Creperie
# 276                  Thai Restaurant
# 181                        Irish Pub
# 138                Korean Restaurant
# 16                 German Restaurant
# 135                 Halal Restaurant
# 196                 Ramen Restaurant
# 69   Southern / Soul Food Restaurant
# 99                     Burrito Place
# 82               Hawaiian Restaurant
# 155                German Restaurant
# 68               Filipino Restaurant
# 126                 Tapas Restaurant
# 226              Hawaiian Restaurant
# 233                Indian Restaurant
# 229                Indian Restaurant
# 213               Israeli Restaurant
# 49                        Taco Place
# 242              Hawaiian Restaurant
# 117              Hawaiian Restaurant
# 103                  Thai Restaurant
# 302                 Halal Restaurant
# 295                 Greek Restaurant
# 289                Indian Restaurant
# 236                Indian Restaurant
# 272                     Noodle House
# 24               Hawaiian Restaurant
# 102              Filipino Restaurant
# 131               Chinese Restaurant
# 160                        Irish Pub
# 183                German Restaurant
# 263                 Greek Restaurant
# 57             Vietnamese Restaurant
# 157              Hawaiian Restaurant
# 109                  Thai Restaurant
# 112            Vietnamese Restaurant
# 121            Australian Restaurant
# 153                 Sushi Restaurant
# 139                 Greek Restaurant
# 119         Mediterranean Restaurant
# 296            Vietnamese Restaurant
# 77                 Indian Restaurant
# 53                 German Restaurant
# 124              Peruvian Restaurant
# 104        Japanese Curry Restaurant
# 6                  German Restaurant
# 83             Vietnamese Restaurant
# 20                         Irish Pub
# 114                 Greek Restaurant
# 250                 Arepa Restaurant
# 92                 German Restaurant
# 125             Caribbean Restaurant
# 115              Hawaiian Restaurant
# 180                Indian Restaurant
# 211                       Taco Place
# 248              Moroccan Restaurant
# 195                German Restaurant
# 36                 German Restaurant
# 96                   Thai Restaurant
# 8                Hawaiian Restaurant
# 161               Israeli Restaurant
# 98                 French Restaurant
# 230            Vietnamese Restaurant
# 147                French Restaurant
# 70                   Thai Restaurant
# 30                 French Restaurant
# 265              Hawaiian Restaurant
# 22               Hawaiian Restaurant
# 205            Vietnamese Restaurant
# 59   Southern / Soul Food Restaurant
# 88         Latin American Restaurant
# 304              Hawaiian Restaurant
# 186                 Cuban Restaurant
# 67             Vietnamese Restaurant
# 145               Spanish Restaurant
# 137              Hawaiian Restaurant
# 293            Vietnamese Restaurant
# 143              Hawaiian Restaurant
# 4                       Noodle House
# 178            Vietnamese Restaurant
# 110            Vietnamese Restaurant
# 288                 Halal Restaurant
# 286              Hawaiian Restaurant
# 38             Vietnamese Restaurant
# 52                 German Restaurant
# 122                German Restaurant
# 97                  Arepa Restaurant
# 35                  Halal Restaurant
# 199                        Irish Pub
# 173        Middle Eastern Restaurant
# 275               Italian Restaurant
# 140               Turkish Restaurant
# 277              Japanese Restaurant
# 48                 German Restaurant
# 271         Mediterranean Restaurant
# 218                French Restaurant
# 120                 Halal Restaurant
# 274                 Sushi Restaurant
# 273                         Sake Bar
# 44                 German Restaurant
# 107              Filipino Restaurant
# 111              Filipino Restaurant
# 264                        Irish Pub
# 32                 French Restaurant
# 280            Vietnamese Restaurant
# 101               Chinese Restaurant
# 201                 Sushi Restaurant
# 18                  Greek Restaurant
# 31                  Greek Restaurant
# 225                 Halal Restaurant
# 61               Szechuan Restaurant
# 58               Filipino Restaurant
# 146             Caribbean Restaurant
# 7                   Greek Restaurant
# 216              Hawaiian Restaurant
# 130                 Halal Restaurant
# 108         Mediterranean Restaurant

# %% [markdown]
# #### Cluster 2

# %%
nyc_merged.loc[nyc_merged['Cluster Labels'] == 1, nyc_merged.columns[[1] + list(range(5, nyc_merged.shape[1]))]]
# Out:
#                           Neighborhood 1st Most Common Venue  \
# 235        Bay Terrace (Staten Island)    Italian Restaurant
# 34                     Belmont (Bronx)    Italian Restaurant
# 208  Castleton Corners (Staten Island)    Italian Restaurant
# 244            Chelsea (Staten Island)    Italian Restaurant
# 12                 City Island (Bronx)    Italian Restaurant
# 254            Concord (Staten Island)    Italian Restaurant
# 231       Dongan Hills (Staten Island)    Italian Restaurant
# 287        Egbertville (Staten Island)    Italian Restaurant
# 255       Emerson Hill (Staten Island)    Italian Restaurant
# 279            Fulton Ferry (Brooklyn)    Italian Restaurant
# 185                 Hillcrest (Queens)    Italian Restaurant
# 133              Howard Beach (Queens)    Italian Restaurant
# 257       Howland Hook (Staten Island)    Italian Restaurant
# 301           Hudson Yards (Manhattan)    Italian Restaurant
# 292    Lighthouse Hill (Staten Island)    Italian Restaurant
# 206   Mariner's Harbor (Staten Island)    Italian Restaurant
# 234     New Dorp Beach (Staten Island)    Italian Restaurant
# 224          Park Hill (Staten Island)    Italian Restaurant
# 37                  Pelham Bay (Bronx)    Italian Restaurant
# 237    Pleasant Plains (Staten Island)    Italian Restaurant
# 251      Richmond Town (Staten Island)    Italian Restaurant
# 200           Rosebank (Staten Island)    Italian Restaurant
# 252        Shore Acres (Staten Island)    Italian Restaurant
# 148          South Ozone Park (Queens)    Italian Restaurant
# 217        Tottenville (Staten Island)    Italian Restaurant
# 210             Travis (Staten Island)    Italian Restaurant
# 123           West Village (Manhattan)    Italian Restaurant
# 150                Whitestone (Queens)    Italian Restaurant
#
#          2nd Most Common Venue  3rd Most Common Venue  \
# 235          French Restaurant       Sushi Restaurant
# 34          Spanish Restaurant     Mexican Restaurant
# 208        Japanese Restaurant        Thai Restaurant
# 244         Spanish Restaurant  Vietnamese Restaurant
# 12           French Restaurant       Tapas Restaurant
# 254        Peruvian Restaurant     Chinese Restaurant
# 231   Mediterranean Restaurant     Chinese Restaurant
# 287      Vietnamese Restaurant   Ethiopian Restaurant
# 255      Vietnamese Restaurant   Ethiopian Restaurant
# 279         Mexican Restaurant       Ramen Restaurant
# 185           Asian Restaurant     Dim Sum Restaurant
# 133         Chinese Restaurant    Japanese Restaurant
# 257         Falafel Restaurant  Vietnamese Restaurant
# 301            Thai Restaurant    Peruvian Restaurant
# 292      Vietnamese Restaurant   Ethiopian Restaurant
# 206  Latin American Restaurant  Vietnamese Restaurant
# 234      Vietnamese Restaurant   Ethiopian Restaurant
# 224      Vietnamese Restaurant   Ethiopian Restaurant
# 37          Mexican Restaurant     Chinese Restaurant
# 237      Vietnamese Restaurant   Ethiopian Restaurant
# 251      Vietnamese Restaurant   Ethiopian Restaurant
# 200         Chinese Restaurant     Mexican Restaurant
# 252         Chinese Restaurant    Filipino Restaurant
# 148      Vietnamese Restaurant   Ethiopian Restaurant
# 217           Asian Restaurant     Mexican Restaurant
# 210         Spanish Restaurant  Vietnamese Restaurant
# 123          French Restaurant      Korean Restaurant
# 150      Vietnamese Restaurant   Ethiopian Restaurant
#
#         4th Most Common Venue            5th Most Common Venue  \
# 235        Chinese Restaurant            Vietnamese Restaurant
# 34         Chinese Restaurant            Vietnamese Restaurant
# 208         Indian Restaurant            Vietnamese Restaurant
# 244      Ethiopian Restaurant              Japanese Restaurant
# 12         Spanish Restaurant            Vietnamese Restaurant
# 254        Mexican Restaurant               Spanish Restaurant
# 231          Sushi Restaurant                 Greek Restaurant
# 287       Japanese Restaurant        Japanese Curry Restaurant
# 255       Japanese Restaurant        Japanese Curry Restaurant
# 279          Sushi Restaurant               Chinese Restaurant
# 185     Vietnamese Restaurant               Falafel Restaurant
# 133          Tapas Restaurant                 Sushi Restaurant
# 257      Ethiopian Restaurant              Japanese Restaurant
# 301        Mexican Restaurant                 Asian Restaurant
# 292       Japanese Restaurant        Japanese Curry Restaurant
# 206          Kebab Restaurant              Japanese Restaurant
# 234       Japanese Restaurant        Japanese Curry Restaurant
# 224       Japanese Restaurant        Japanese Curry Restaurant
# 37            Thai Restaurant                 Asian Restaurant
# 237       Japanese Restaurant        Japanese Curry Restaurant
# 251       Japanese Restaurant        Japanese Curry Restaurant
# 200       Filipino Restaurant            Vietnamese Restaurant
# 252     Vietnamese Restaurant             Ethiopian Restaurant
# 148       Japanese Restaurant        Japanese Curry Restaurant
# 217     Vietnamese Restaurant               Falafel Restaurant
# 210      Ethiopian Restaurant              Japanese Restaurant
# 123  Mediterranean Restaurant  Southern / Soul Food Restaurant
# 150       Japanese Restaurant        Japanese Curry Restaurant
#
#          6th Most Common Venue      7th Most Common Venue  \
# 235           Halal Restaurant        Filipino Restaurant
# 34         Filipino Restaurant          French Restaurant
# 208       Ethiopian Restaurant  Japanese Curry Restaurant
# 244  Japanese Curry Restaurant         Israeli Restaurant
# 12            Greek Restaurant         Falafel Restaurant
# 254           Halal Restaurant          French Restaurant
# 231         Mexican Restaurant         Spanish Restaurant
# 287         Israeli Restaurant                  Irish Pub
# 255         Israeli Restaurant                  Irish Pub
# 279  Middle Eastern Restaurant         Falafel Restaurant
# 185        Japanese Restaurant  Japanese Curry Restaurant
# 133         Mexican Restaurant                  Irish Pub
# 257  Japanese Curry Restaurant         Israeli Restaurant
# 301               Noodle House          Indian Restaurant
# 292         Israeli Restaurant                  Irish Pub
# 206  Japanese Curry Restaurant         Israeli Restaurant
# 234         Israeli Restaurant                  Irish Pub
# 224         Israeli Restaurant                  Irish Pub
# 37   Latin American Restaurant      Vietnamese Restaurant
# 237         Israeli Restaurant                  Irish Pub
# 251         Israeli Restaurant                  Irish Pub
# 200         Falafel Restaurant        Japanese Restaurant
# 252        Japanese Restaurant  Japanese Curry Restaurant
# 148         Israeli Restaurant                  Irish Pub
# 217        Japanese Restaurant  Japanese Curry Restaurant
# 210  Japanese Curry Restaurant         Israeli Restaurant
# 123               Noodle House         Chinese Restaurant
# 150         Israeli Restaurant                  Irish Pub
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 235          German Restaurant      Greek Restaurant    Hawaiian Restaurant
# 34           German Restaurant      Greek Restaurant    Hawaiian Restaurant
# 208         Israeli Restaurant             Irish Pub    Hawaiian Restaurant
# 244                  Irish Pub     Indian Restaurant    Hawaiian Restaurant
# 12         Filipino Restaurant     German Restaurant    Hawaiian Restaurant
# 254          German Restaurant      Greek Restaurant  Vietnamese Restaurant
# 231      Vietnamese Restaurant   Filipino Restaurant      French Restaurant
# 287          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant
# 255          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant
# 279          Indian Restaurant      Halal Restaurant    Hawaiian Restaurant
# 185         Israeli Restaurant             Irish Pub      Indian Restaurant
# 133          Indian Restaurant   Hawaiian Restaurant   Ethiopian Restaurant
# 257                  Irish Pub     Indian Restaurant    Hawaiian Restaurant
# 301                 Taco Place   Filipino Restaurant      French Restaurant
# 292          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant
# 206                  Irish Pub     Indian Restaurant    Hawaiian Restaurant
# 234          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant
# 224          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant
# 37         Hawaiian Restaurant     French Restaurant      German Restaurant
# 237          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant
# 251          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant
# 200  Japanese Curry Restaurant    Israeli Restaurant              Irish Pub
# 252         Israeli Restaurant             Irish Pub      Indian Restaurant
# 148          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant
# 217         Israeli Restaurant             Irish Pub      Indian Restaurant
# 210                  Irish Pub     Indian Restaurant    Hawaiian Restaurant
# 123         Mexican Restaurant    Falafel Restaurant       Halal Restaurant
# 150          Indian Restaurant   Hawaiian Restaurant       Halal Restaurant

# %% [markdown]
# #### Cluster 3

# %%
nyc_merged.loc[nyc_merged['Cluster Labels'] == 2, nyc_merged.columns[[1] + list(range(5, nyc_merged.shape[1]))]]
# 223               Chinese Restaurant  Southern / Soul Food Restaurant
# 164               Chinese Restaurant                Indian Restaurant
# 165               Chinese Restaurant                 Asian Restaurant
# 73                  Sushi Restaurant               Chinese Restaurant
# 0                   Asian Restaurant               Spanish Restaurant
# 281               Chinese Restaurant  Southern / Soul Food Restaurant
# 9                 Chinese Restaurant               African Restaurant
# 222            Vietnamese Restaurant        Latin American Restaurant
#
#                4th Most Common Venue            5th Most Common Venue  \
# 227               Falafel Restaurant              Japanese Restaurant
# 168            Vietnamese Restaurant                French Restaurant
# 74                   Thai Restaurant                 Asian Restaurant
# 105  Southern / Soul Food Restaurant               African Restaurant
# 267               Spanish Restaurant               African Restaurant
# 55                Chinese Restaurant  Southern / Soul Food Restaurant
# 221                       Taco Place                 Ramen Restaurant
# 141        Latin American Restaurant                 Asian Restaurant
# 56                Falafel Restaurant              Japanese Restaurant
# 2              Vietnamese Restaurant                French Restaurant
# 45                Falafel Restaurant              Japanese Restaurant
# 300               African Restaurant                French Restaurant
# 75                  Sushi Restaurant                French Restaurant
# 163               Spanish Restaurant                French Restaurant
# 182              Filipino Restaurant                French Restaurant
# 188               Falafel Restaurant              Japanese Restaurant
# 89                African Restaurant               Falafel Restaurant
# 41         Latin American Restaurant            Vietnamese Restaurant
# 93   Southern / Soul Food Restaurant              Japanese Restaurant
# 162               Mexican Restaurant               Spanish Restaurant
# 259  Southern / Soul Food Restaurant                French Restaurant
# 166                 Sushi Restaurant              Japanese Restaurant
# 169               Falafel Restaurant              Japanese Restaurant
# 223            Vietnamese Restaurant                French Restaurant
# 164            Vietnamese Restaurant               Falafel Restaurant
# 165  Southern / Soul Food Restaurant                French Restaurant
# 73             Vietnamese Restaurant                French Restaurant
# 0              Vietnamese Restaurant                French Restaurant
# 281                 Asian Restaurant               Israeli Restaurant
# 9                   Cuban Restaurant                Indian Restaurant
# 222                 Arepa Restaurant               Chinese Restaurant
#
#                6th Most Common Venue      7th Most Common Venue  \
# 227        Japanese Curry Restaurant         Italian Restaurant
# 168                German Restaurant           Greek Restaurant
# 74         Middle Eastern Restaurant                 Taco Place
# 105               Italian Restaurant         Tex-Mex Restaurant
# 267                        Irish Pub          Indian Restaurant
# 55                Mexican Restaurant         Falafel Restaurant
# 221               Spanish Restaurant        Filipino Restaurant
# 141                German Restaurant           Greek Restaurant
# 56         Japanese Curry Restaurant         Italian Restaurant
# 2                  German Restaurant           Greek Restaurant
# 45         Japanese Curry Restaurant         Italian Restaurant
# 300  Southern / Soul Food Restaurant          German Restaurant
# 75                 German Restaurant           Greek Restaurant
# 163                German Restaurant           Greek Restaurant
# 182                German Restaurant           Greek Restaurant
# 188        Japanese Curry Restaurant         Italian Restaurant
# 89                 French Restaurant          German Restaurant
# 41                 French Restaurant          German Restaurant
# 93                  Asian Restaurant  Latin American Restaurant
# 162              Filipino Restaurant                  Irish Pub
# 259                German Restaurant           Greek Restaurant
# 166                 Asian Restaurant         Israeli Restaurant
# 169        Japanese Curry Restaurant         Italian Restaurant
# 223                German Restaurant           Greek Restaurant
# 164              Japanese Restaurant  Japanese Curry Restaurant
# 165                German Restaurant           Greek Restaurant
# 73                 German Restaurant           Greek Restaurant
# 0                  German Restaurant           Greek Restaurant
# 281                Indian Restaurant        Hawaiian Restaurant
# 9                  French Restaurant          German Restaurant
# 222                Indian Restaurant         African Restaurant
#
#     8th Most Common Venue            9th Most Common Venue  \
# 227    Israeli Restaurant                        Irish Pub
# 168      Halal Restaurant              Hawaiian Restaurant
# 74       Halal Restaurant                French Restaurant
# 105      Tapas Restaurant             Ethiopian Restaurant
# 267   Hawaiian Restaurant                 Halal Restaurant
# 55      French Restaurant                German Restaurant
# 221    Mexican Restaurant  Southern / Soul Food Restaurant
# 141      Halal Restaurant              Hawaiian Restaurant
# 56     Israeli Restaurant                        Irish Pub
# 2        Halal Restaurant              Hawaiian Restaurant
# 45     Israeli Restaurant                        Irish Pub
# 300      Greek Restaurant                 Halal Restaurant
# 75       Halal Restaurant              Hawaiian Restaurant
# 163      Halal Restaurant              Hawaiian Restaurant
# 182      Halal Restaurant              Hawaiian Restaurant
# 188    Israeli Restaurant                        Irish Pub
# 89       Greek Restaurant                 Halal Restaurant
# 41       Greek Restaurant                 Halal Restaurant
# 93      Indian Restaurant                       Taco Place
# 162     Indian Restaurant               Israeli Restaurant
# 259      Halal Restaurant              Hawaiian Restaurant
# 166             Irish Pub                Indian Restaurant
# 169    Israeli Restaurant                        Irish Pub
# 223      Halal Restaurant              Hawaiian Restaurant
# 164    Italian Restaurant               Israeli Restaurant
# 165      Halal Restaurant              Hawaiian Restaurant
# 73       Halal Restaurant              Hawaiian Restaurant
# 0        Halal Restaurant              Hawaiian Restaurant
# 281     French Restaurant                German Restaurant
# 9        Greek Restaurant                 Halal Restaurant
# 222  Taiwanese Restaurant                       Taco Place
#
#         10th Most Common Venue
# 227          Indian Restaurant
# 168          Indian Restaurant
# 74           German Restaurant
# 105        Filipino Restaurant
# 267       Ethiopian Restaurant
# 55            Greek Restaurant
# 221  Latin American Restaurant
# 141          Indian Restaurant
# 56           Indian Restaurant
# 2            Indian Restaurant
# 45           Indian Restaurant
# 300        Hawaiian Restaurant
# 75       Vietnamese Restaurant
# 163      Vietnamese Restaurant
# 182       Ethiopian Restaurant
# 188          Indian Restaurant
# 89         Hawaiian Restaurant
# 41         Hawaiian Restaurant
# 93       Vietnamese Restaurant
# 162         Falafel Restaurant
# 259      Vietnamese Restaurant
# 166        Hawaiian Restaurant
# 169          Indian Restaurant
# 223         Falafel Restaurant
# 164                  Irish Pub
# 165      Vietnamese Restaurant
# 73          Falafel Restaurant
# 0            Indian Restaurant
# 281           Greek Restaurant
# 9          Hawaiian Restaurant
# 222         Israeli Restaurant

# %% [markdown]
# #### Cluster 4

# %%
nyc_merged.loc[nyc_merged['Cluster Labels'] == 3, nyc_merged.columns[[1] + list(range(5, nyc_merged.shape[1]))]]
# Out:
#                           Neighborhood      1st Most Common Venue  \
# 298                   Allerton (Bronx)         Mexican Restaurant
# 177                   Arverne (Queens)            Thai Restaurant
# 266           Astoria Heights (Queens)         Italian Restaurant
# 10                  Baychester (Bronx)         Chinese Restaurant
# 13                Bedford Park (Bronx)         Mexican Restaurant
# 174                Beechhurst (Queens)         Chinese Restaurant
# 194                  Bellaire (Queens)         Chinese Restaurant
# 190              Belle Harbor (Queens)         Italian Restaurant
# 156                 Bellerose (Queens)         Chinese Restaurant
# 47              Bensonhurst (Brooklyn)         Chinese Restaurant
# 297                  Bronxdale (Bronx)         Chinese Restaurant
# 60              Brownsville (Brooklyn)         Chinese Restaurant
# 100              Chinatown (Manhattan)         Chinese Restaurant
# 90                City Line (Brooklyn)         Chinese Restaurant
# 253            Clifton (Staten Island)         Mexican Restaurant
# 1                   Co-op City (Bronx)         Chinese Restaurant
# 43                   Concourse (Bronx)         Chinese Restaurant
# 29                Country Club (Bronx)         Italian Restaurant
# 72            East New York (Brooklyn)         Chinese Restaurant
# 176                  Edgemere (Queens)         Chinese Restaurant
# 39              Edgewater Park (Bronx)         Italian Restaurant
# 170              Far Rockaway (Queens)         Chinese Restaurant
# 305          Fox Hills (Staten Island)         Chinese Restaurant
# 158             Fresh Meadows (Queens)         Chinese Restaurant
# 94               Georgetown (Brooklyn)         Chinese Restaurant
# 144                  Glendale (Queens)         Chinese Restaurant
# 50                Gravesend (Brooklyn)         Italian Restaurant
# 202        Grymes Hill (Staten Island)         African Restaurant
# 243  Heartland Village (Staten Island)  Middle Eastern Restaurant
# 19                High  Bridge (Bronx)         Chinese Restaurant
# 136               Kew Gardens (Queens)         Chinese Restaurant
# 5                  Kingsbridge (Bronx)         Chinese Restaurant
# 299        Kingsbridge Heights (Bronx)         Chinese Restaurant
# 189               Lefrak City (Queens)         Chinese Restaurant
# 187                Lindenwood (Queens)        Japanese Restaurant
# 23                    Longwood (Bronx)         Chinese Restaurant
# 294                     Malba (Queens)  Latin American Restaurant
# 284      Manor Heights (Staten Island)           Sushi Restaurant
# 142                   Maspeth (Queens)         Chinese Restaurant
# 290            Middle Village (Queens)         Chinese Restaurant
# 232      Midland Beach (Staten Island)         Italian Restaurant
# 262              Mill Basin (Brooklyn)         Chinese Restaurant
# 15              Morris Heights (Bronx)         Chinese Restaurant
# 33                 Morris Park (Bronx)         Chinese Restaurant
# 25                  Morrisania (Bronx)         Chinese Restaurant
# 21                  Mott Haven (Bronx)         Chinese Restaurant
# 269                 Mount Eden (Bronx)         Chinese Restaurant
# 270                 Mount Hope (Bronx)         Chinese Restaurant
# 198       New Brighton (Staten Island)         Chinese Restaurant
# 260                New Lots (Brooklyn)         Chinese Restaurant
# 209    New Springville (Staten Island)  Middle Eastern Restaurant
# 261         Paerdegat Basin (Brooklyn)         Chinese Restaurant
# 42              Pelham Gardens (Bronx)         Spanish Restaurant
# 11              Pelham Parkway (Bronx)         Chinese Restaurant
# 291       Prince's Bay (Staten Island)         Italian Restaurant
# 184           Queensboro Hill (Queens)         Chinese Restaurant
# 256      Randall Manor (Staten Island)         Chinese Restaurant
# 191             Rockaway Park (Queens)         Chinese Restaurant
# 240          Rossville (Staten Island)         Chinese Restaurant
# 85                 Sea Gate (Brooklyn)         Chinese Restaurant
# 291         Chinese Restaurant                 Sushi Restaurant
# 184           Asian Restaurant               Dim Sum Restaurant
# 256      Vietnamese Restaurant             Ethiopian Restaurant
# 191        Japanese Restaurant         Mediterranean Restaurant
# 240           Greek Restaurant            Vietnamese Restaurant
# 85       Vietnamese Restaurant             Ethiopian Restaurant
# 192      Vietnamese Restaurant             Ethiopian Restaurant
# 26          Spanish Restaurant        Latin American Restaurant
# 167       Caribbean Restaurant            Vietnamese Restaurant
# 197         Italian Restaurant               Spanish Restaurant
# 220         Mexican Restaurant            Vietnamese Restaurant
# 28         Japanese Restaurant                 Asian Restaurant
# 14          African Restaurant               Spanish Restaurant
# 285          Jewish Restaurant                 Greek Restaurant
#
#                4th Most Common Venue      5th Most Common Venue  \
# 298            Vietnamese Restaurant           Halal Restaurant
# 177              Hawaiian Restaurant        Filipino Restaurant
# 266                 Greek Restaurant      Vietnamese Restaurant
# 10             Vietnamese Restaurant           Halal Restaurant
# 13                Spanish Restaurant        Hawaiian Restaurant
# 174            Vietnamese Restaurant         Falafel Restaurant
# 194                 Halal Restaurant           Greek Restaurant
# 190            Vietnamese Restaurant         Falafel Restaurant
# 156           Argentinian Restaurant           Asian Restaurant
# 47                  Sushi Restaurant           Asian Restaurant
# 297               Spanish Restaurant       Caribbean Restaurant
# 60             Vietnamese Restaurant          French Restaurant
# 100              Dumpling Restaurant           Greek Restaurant
# 90                  Cuban Restaurant         Spanish Restaurant
# 253            Vietnamese Restaurant         Falafel Restaurant
# 1                 Spanish Restaurant         Falafel Restaurant
# 43         Latin American Restaurant         Mexican Restaurant
# 29             Vietnamese Restaurant         Falafel Restaurant
# 72                Spanish Restaurant           Asian Restaurant
# 176               Falafel Restaurant        Japanese Restaurant
# 39                  Asian Restaurant      Vietnamese Restaurant
# 170  Southern / Soul Food Restaurant      Vietnamese Restaurant
# 305               Spanish Restaurant       Caribbean Restaurant
# 158               African Restaurant  Middle Eastern Restaurant
# 94                  Asian Restaurant       Caribbean Restaurant
# 144            Vietnamese Restaurant         Falafel Restaurant
# 50                Dim Sum Restaurant        Hawaiian Restaurant
# 202              Japanese Restaurant  Japanese Curry Restaurant
# 243               Mexican Restaurant         Falafel Restaurant
# 19              Caribbean Restaurant         Spanish Restaurant
# 136              Japanese Restaurant  Latin American Restaurant
# 5               Caribbean Restaurant           Asian Restaurant
# 299            Vietnamese Restaurant         Spanish Restaurant
# 189               Mexican Restaurant         Falafel Restaurant
# 187            Vietnamese Restaurant           Halal Restaurant
# 23   Southern / Soul Food Restaurant         Spanish Restaurant
# 294            Vietnamese Restaurant         Falafel Restaurant
# 284                 Halal Restaurant        Filipino Restaurant
# 142               Italian Restaurant           Sushi Restaurant
# 290               Italian Restaurant        Japanese Restaurant
# 232            Vietnamese Restaurant         Falafel Restaurant
# 262                 Sushi Restaurant  Middle Eastern Restaurant
# 15         Latin American Restaurant          Paella Restaurant
# 33                Italian Restaurant   Mediterranean Restaurant
# 25                Mexican Restaurant      Vietnamese Restaurant
# 21                  Arepa Restaurant           Asian Restaurant
# 269               Spanish Restaurant        Hawaiian Restaurant
# 270               Spanish Restaurant         Mexican Restaurant
# 198                 Greek Restaurant         Spanish Restaurant
# 260        Latin American Restaurant           Asian Restaurant
# 209            Vietnamese Restaurant         Falafel Restaurant
# 261            Vietnamese Restaurant          French Restaurant
# 42                Italian Restaurant      Vietnamese Restaurant
# 11                   Thai Restaurant           Sushi Restaurant
# 291            Vietnamese Restaurant           Halal Restaurant
# 184              Dumpling Restaurant           Malay Restaurant
# 256              Japanese Restaurant  Japanese Curry Restaurant
# 191                French Restaurant         Spanish Restaurant
# 240             Ethiopian Restaurant        Japanese Restaurant
# 85               Japanese Restaurant  Japanese Curry Restaurant
# 192              Japanese Restaurant  Japanese Curry Restaurant
# 26   Southern / Soul Food Restaurant      Vietnamese Restaurant
# 167               Falafel Restaurant        Japanese Restaurant
# 197               Falafel Restaurant       Caribbean Restaurant
# 220               Falafel Restaurant        Japanese Restaurant
# 28                Italian Restaurant      Vietnamese Restaurant
# 14         Latin American Restaurant         Mexican Restaurant
# 285                 Cuban Restaurant        Filipino Restaurant
#
#                6th Most Common Venue      7th Most Common Venue  \
# 298              Filipino Restaurant          French Restaurant
# 177                French Restaurant          German Restaurant
# 266                 Halal Restaurant        Filipino Restaurant
# 10               Filipino Restaurant          French Restaurant
# 13                 French Restaurant          German Restaurant
# 174              Japanese Restaurant  Japanese Curry Restaurant
# 194            Vietnamese Restaurant       Ethiopian Restaurant
# 190              Japanese Restaurant  Japanese Curry Restaurant
# 156                Indian Restaurant      Vietnamese Restaurant
# 47         Latin American Restaurant        Dumpling Restaurant
# 297        Latin American Restaurant        Hawaiian Restaurant
# 60                 German Restaurant           Greek Restaurant
# 100               Italian Restaurant               Noodle House
# 90                Mexican Restaurant          German Restaurant
# 253              Japanese Restaurant  Japanese Curry Restaurant
# 1                  French Restaurant          German Restaurant
# 43                Italian Restaurant                 Taco Place
# 29               Japanese Restaurant  Japanese Curry Restaurant
# 72   Southern / Soul Food Restaurant        Hawaiian Restaurant
# 176        Japanese Curry Restaurant         Italian Restaurant
# 39                Falafel Restaurant  Japanese Curry Restaurant
# 170                French Restaurant          German Restaurant
# 305                        Irish Pub          Indian Restaurant
# 158              Japanese Restaurant                Beer Garden
# 94             Vietnamese Restaurant        Hawaiian Restaurant
# 144              Japanese Restaurant  Japanese Curry Restaurant
# 50                 French Restaurant          German Restaurant
# 202               Italian Restaurant         Israeli Restaurant
# 243        Japanese Curry Restaurant         Italian Restaurant
# 19                Mexican Restaurant         Falafel Restaurant
# 136                Indian Restaurant        Peruvian Restaurant
# 5                 Spanish Restaurant          German Restaurant
# 299        Latin American Restaurant  Middle Eastern Restaurant
# 189        Japanese Curry Restaurant         Italian Restaurant
# 187              Filipino Restaurant          French Restaurant
# 23             Vietnamese Restaurant        Filipino Restaurant
# 294              Japanese Restaurant  Japanese Curry Restaurant
# 284                French Restaurant          German Restaurant
# 142               Israeli Restaurant                  Irish Pub
# 290                       Taco Place         Spanish Restaurant
# 232              Japanese Restaurant  Japanese Curry Restaurant
# 262              Peruvian Restaurant          French Restaurant
# 15                  Asian Restaurant              Burrito Place
# 33                 French Restaurant          German Restaurant
# 25                 French Restaurant          German Restaurant
# 21         Latin American Restaurant         Mexican Restaurant
# 269                French Restaurant          German Restaurant
# 270               Israeli Restaurant                  Irish Pub
# 198                French Restaurant          German Restaurant
# 260                French Restaurant          German Restaurant
# 209        Japanese Curry Restaurant         Italian Restaurant
# 261                German Restaurant           Greek Restaurant
# 42                 French Restaurant          German Restaurant
# 11                  Halal Restaurant        Filipino Restaurant
# 291              Filipino Restaurant          French Restaurant
# 184               Spanish Restaurant          Indian Restaurant
# 256               Italian Restaurant         Israeli Restaurant
# 191               Mexican Restaurant         Italian Restaurant
# 240        Japanese Curry Restaurant         Italian Restaurant
# 85                Italian Restaurant         Israeli Restaurant
# 192               Italian Restaurant         Israeli Restaurant
# 26               Filipino Restaurant          French Restaurant
# 167        Japanese Curry Restaurant         Italian Restaurant
# 197                  Thai Restaurant           Tapas Restaurant
# 220        Japanese Curry Restaurant         Italian Restaurant
# 28                Falafel Restaurant  Japanese Curry Restaurant
# 14              Caribbean Restaurant                  Irish Pub
# 285               Falafel Restaurant        Japanese Restaurant
#
#          8th Most Common Venue      9th Most Common Venue  \
# 298          German Restaurant           Greek Restaurant
# 177           Greek Restaurant           Halal Restaurant
# 266          French Restaurant          German Restaurant
# 10           German Restaurant           Greek Restaurant
# 13            Greek Restaurant           Halal Restaurant
# 174         Israeli Restaurant                  Irish Pub
# 194        Japanese Restaurant  Japanese Curry Restaurant
# 190         Israeli Restaurant                  Irish Pub
# 156           Halal Restaurant          French Restaurant
# 47                Noodle House          German Restaurant
# 297          French Restaurant          German Restaurant
# 60            Halal Restaurant        Hawaiian Restaurant
# 100      Australian Restaurant                Beer Garden
# 90            Greek Restaurant           Halal Restaurant
# 253         Israeli Restaurant                  Irish Pub
# 1             Greek Restaurant           Halal Restaurant
# 43          Spanish Restaurant                  Irish Pub
# 29          Israeli Restaurant                  Irish Pub
# 72           French Restaurant          German Restaurant
# 176         Israeli Restaurant                  Irish Pub
# 39          Israeli Restaurant                  Irish Pub
# 170           Greek Restaurant           Halal Restaurant
# 305        Hawaiian Restaurant           Halal Restaurant
# 158              Burrito Place  Japanese Curry Restaurant
# 94           French Restaurant          German Restaurant
# 144         Israeli Restaurant                  Irish Pub
# 50            Greek Restaurant           Halal Restaurant
# 202                  Irish Pub          Indian Restaurant
# 243         Israeli Restaurant                  Irish Pub
# 19          Italian Restaurant                  Irish Pub
# 136           Sushi Restaurant         Spanish Restaurant
# 5             Greek Restaurant           Halal Restaurant
# 299         African Restaurant                 Taco Place
# 189         Israeli Restaurant                  Irish Pub
# 187          German Restaurant           Greek Restaurant
# 23           French Restaurant          German Restaurant
# 294         Israeli Restaurant                  Irish Pub
# 284           Greek Restaurant        Hawaiian Restaurant
# 142          Indian Restaurant        Hawaiian Restaurant
# 290         Falafel Restaurant        Filipino Restaurant
# 232         Israeli Restaurant                  Irish Pub
# 262          German Restaurant           Greek Restaurant
# 15          Mexican Restaurant          German Restaurant
# 33            Greek Restaurant           Halal Restaurant
# 25            Greek Restaurant           Halal Restaurant
# 21         Peruvian Restaurant           Cuban Restaurant
# 269           Greek Restaurant           Halal Restaurant
# 270          Indian Restaurant         Falafel Restaurant
# 198           Halal Restaurant      Vietnamese Restaurant
# 260           Greek Restaurant           Halal Restaurant
# 209         Israeli Restaurant                  Irish Pub
# 261           Halal Restaurant        Hawaiian Restaurant
# 42            Greek Restaurant           Halal Restaurant
# 11           French Restaurant          German Restaurant
# 291          German Restaurant           Greek Restaurant
# 184       Cantonese Restaurant       Taiwanese Restaurant
# 256                  Irish Pub          Indian Restaurant
# 191          Indian Restaurant                  Irish Pub
# 240         Israeli Restaurant                  Irish Pub
# 85                   Irish Pub          Indian Restaurant
# 192                  Irish Pub          Indian Restaurant
# 26           German Restaurant           Greek Restaurant
# 167         Israeli Restaurant                  Irish Pub
# 197           Greek Restaurant        Filipino Restaurant
# 220         Israeli Restaurant                  Irish Pub
# 28          Israeli Restaurant                  Irish Pub
# 14           Indian Restaurant         Israeli Restaurant
# 285  Japanese Curry Restaurant         Italian Restaurant
#
#               10th Most Common Venue
# 298              Hawaiian Restaurant
# 177                Indian Restaurant
# 266              Hawaiian Restaurant
# 10               Hawaiian Restaurant
# 13             Vietnamese Restaurant
# 174                Indian Restaurant
# 194               Israeli Restaurant
# 190                Indian Restaurant
# 156                German Restaurant
# 47                  Greek Restaurant
# 297                 Greek Restaurant
# 60                Falafel Restaurant
# 100             Cantonese Restaurant
# 90               Hawaiian Restaurant
# 253                Indian Restaurant
# 1              Vietnamese Restaurant
# 43                 Indian Restaurant
# 29                 Indian Restaurant
# 72                  Greek Restaurant
# 176                Indian Restaurant
# 39                 Indian Restaurant
# 170              Hawaiian Restaurant
# 305             Ethiopian Restaurant
# 158               Italian Restaurant
# 94                  Greek Restaurant
# 144                Indian Restaurant
# 50             Vietnamese Restaurant
# 202              Hawaiian Restaurant
# 243                Indian Restaurant
# 19                 Indian Restaurant
# 136  Southern / Soul Food Restaurant
# 5                Hawaiian Restaurant
# 299              Dumpling Restaurant
# 189                Indian Restaurant
# 187              Hawaiian Restaurant
# 23                  Greek Restaurant
# 294                Indian Restaurant
# 284             Ethiopian Restaurant
# 142             Ethiopian Restaurant
# 290                French Restaurant
# 232                Indian Restaurant
# 262                 Halal Restaurant
# 15                  Greek Restaurant
# 33               Hawaiian Restaurant
# 25               Hawaiian Restaurant
# 21                 German Restaurant
# 269            Vietnamese Restaurant
# 270              Hawaiian Restaurant
# 198               Falafel Restaurant
# 260              Hawaiian Restaurant
# 209                Indian Restaurant
# 261                Indian Restaurant
# 42               Hawaiian Restaurant
# 11                  Greek Restaurant
# 291              Hawaiian Restaurant
# 184              Filipino Restaurant
# 256              Hawaiian Restaurant
# 191               Falafel Restaurant
# 240                Indian Restaurant
# 85               Hawaiian Restaurant
# 192              Hawaiian Restaurant
# 26                  Halal Restaurant
# 167                Indian Restaurant
# 197                French Restaurant
# 220                Indian Restaurant
# 28                 Indian Restaurant
# 14                Falafel Restaurant
# 285               Israeli Restaurant
